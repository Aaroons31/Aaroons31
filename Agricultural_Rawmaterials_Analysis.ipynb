# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaroons31/Aaroons31/blob/main/Agricultural_Rawmaterials_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Sample data for demonstration (replace with actual dataset)
data = {
    'Crop': ['Rice', 'Wheat', 'Cotton', 'Maize', 'Sugarcane'],
    'Yield (kg/hectare)': [3000, 2500, 2200, 4000, 3500],
    'Cost per kg (INR)': [20, 25, 35, 18, 22],
    'Market Price per kg (INR)': [30, 35, 40, 28, 25],
    'Quality Rating': [8, 7, 6, 9, 8]
}

# Creating a pandas DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the dataframe
print(df.head())
# Out:
#         Crop  Yield (kg/hectare)  Cost per kg (INR)  \
# 0       Rice                3000                 20
# 1      Wheat                2500                 25
# 2     Cotton                2200                 35
# 3      Maize                4000                 18
# 4  Sugarcane                3500                 22
#
#    Market Price per kg (INR)  Quality Rating
# 0                         30               8
# 1                         35               7
# 2                         40               6
# 3                         28               9
# 4                         25               8

# %%
# Add a new column for profitability per kg
df['Profit per kg (INR)'] = df['Market Price per kg (INR)'] - df['Cost per kg (INR)']

# Calculate total profit per crop (Profit per kg * Yield per hectare)
df['Total Profit (INR)'] = df['Profit per kg (INR)'] * df['Yield (kg/hectare)']

# Display the updated dataframe
print(df)

# Basic Statistical Analysis
print("\nStatistical Summary:")
print(df.describe())
# Out:
#         Crop  Yield (kg/hectare)  Cost per kg (INR)  \
# 0       Rice                3000                 20
# 1      Wheat                2500                 25
# 2     Cotton                2200                 35
# 3      Maize                4000                 18
# 4  Sugarcane                3500                 22
#
#    Market Price per kg (INR)  Quality Rating  Profit per kg (INR)  \
# 0                         30               8                   10
# 1                         35               7                   10
# 2                         40               6                    5
# 3                         28               9                   10
# 4                         25               8                    3
#
#    Total Profit (INR)
# 0               30000
# 1               25000
# 2               11000
# 3               40000
# 4               10500
#
# Statistical Summary:
#        Yield (kg/hectare)  Cost per kg (INR)  Market Price per kg (INR)  \
# ...

# %%
# Plotting Yield vs. Market Price
plt.figure(figsize=(10, 6))
sns.barplot(x='Crop', y='Yield (kg/hectare)', data=df, palette='Set2')
plt.title('Crop Yield Comparison')
plt.ylabel('Yield (kg/hectare)')
plt.show()

# Plotting Total Profit per Crop
plt.figure(figsize=(10, 6))
sns.barplot(x='Crop', y='Total Profit (INR)', data=df, palette='Blues')
plt.title('Total Profit per Crop')
plt.ylabel('Total Profit (INR)')
plt.show()
# Out:
# <ipython-input-6-71d04bd7a015>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crop', y='Yield (kg/hectare)', data=df, palette='Set2')
# <ipython-input-6-71d04bd7a015>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Crop', y='Total Profit (INR)', data=df, palette='Blues')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix, excluding non-numeric columns
correlation_matrix = df.select_dtypes(include=['number']).corr() # Select only numeric columns

# Create the heatmap
plt.figure(figsize=(10, 8))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
